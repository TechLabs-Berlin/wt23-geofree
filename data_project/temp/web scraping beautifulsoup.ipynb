# %% [markdown]
# # GEOFREE - Data Project

# %% [markdown]
# ### Web scraping with BeautifulSoup

# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
# Connect to Website and pull in data

URL = 'https://www.free-your-stuff.com/de/berlin'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

# title = soup2.find(id='productTitle').get_text()

# https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data%2Banalyst%2Btshirt&qid=1626655184&sr=8-3&customId=B0752XJYNL&th=1


# price = soup2.find(id='priceblock_ourprice').get_text()

# print(soup1)
print(soup2)
# print(title)
# print(price)
# Out:
# <!DOCTYPE html>
#
# <html lang="de">
# <head>
# <meta charset="utf-8"/>
# <title>
#    Free Your Stuff Berlin | Die Verschenk-Community
#   </title>
# <base href="https://www.free-your-stuff.com/de"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="FQh1ub7LEYlMTvQxkqk5tcaP6CRiG4vN4UrKd8N9" name="_token"/>
# <meta content="Wegwerfen war gestern, heute wird verschenkt. Auch die Community in Berlin macht fleißig mit. Es ist kostenlos, kinderleicht und macht Spaß." name="description"/>
# <meta content="free, your, stuff, geschenke erhalten, kostenlos, gives, needs, kostenlose Kleinanzeigen, verschenken, Verschenkplattform in Deutschland" name="keywords">
# <meta content="index, follow" name="robots">
# <meta content="Free Your Stuff Berlin | Die Verschenk-Community" name="original-title"/>
# <!-- Facebook opengraph -->
# <meta content="Free Your Stuff Berlin | Die Verschenk-Community" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.free-your-stuff.com/de/berlin" property="og:url"/>
# <meta content="https://www.free-your-stuff.com/images/icons/android-chrome-192x192.png" property="og:image"/>
# <meta content="Wegwerfen war gestern, heute wird verschenkt. Auch die Community in Berlin macht fleißig mit. Es ist kostenlos, kinderleicht und macht Spaß." property="og:description"/>
# <meta content="Free Your Stuff" property="og:site_name"/>
# <meta content="562830537157407" property="fb:app_id"/>
# <link href="/images/icons/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/images/icons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/images/icons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/images/icons/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/images/icons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/images/icons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/images/icons/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/images/icons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/images/icons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/images/icons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/images/icons/favicon-194x194.png" rel="icon" sizes="194x194" type="image/png"/>
# <link href="/images/icons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/images/icons/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/images/icons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/images/icons/manifest.json" rel="manifest"/>
# <link color="#5bbad5" href="/images/icons/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="Free Your Stuff" name="apple-mobile-web-app-title"/>
# <meta content="Free Your Stuff" name="application-name"/>
# <meta content="#da532c" name="msapplication-TileColor"/>
# <meta content="/images/icons/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <!-- Loading Bootstrap -->
# <link href="https://www.free-your-stuff.com/bootstrap/css/bootstrap.css?v=1449530170" rel="stylesheet"/>
# <link href="https://www.free-your-stuff.com/css/social-buttons.css?v=1467236556" rel="stylesheet"/>
# <link href="https://www.free-your-stuff.com/css/azm.css?v=1453483350" rel="stylesheet"/>
# <link href="https://www.free-your-stuff.com/css/swal.css?v=1513201911" rel="stylesheet"/>
# <link href="https://www.free-your-stuff.com/css/tipso.css?v=1513201916" rel="stylesheet"/>
# <link href="https://www.free-your-stuff.com/css/micons.css?v=1513201915" rel="stylesheet"/>
# <link href="https://www.free-your-stuff.com/css/hmin.css?v=1513201910" rel="stylesheet"/>
# <!-- Loading Flat UI -->
# <link href="https://www.free-your-stuff.com/css/sumoselect.css?v=1449530134" rel="stylesheet"/>
# <link href="https://www.free-your-stuff.com/css/lightbox.css?v=1449530132" rel="stylesheet"/>
# <!-- Loading Main CSS -->
# <link href="https://www.free-your-stuff.com/css/main.css?v=1513201914" rel="stylesheet"/>
# <link href="https://www.free-your-stuff.com/css/app2.css?v=1513201912" rel="stylesheet"/>
# <!-- HTML5 shim, for IE6-8 support of HTML5 elements. All other JS at the end of file. -->
# <!--[if lt IE 9]>
#       <script src="js/html5shiv.js"></script>
#       <script src="js/respond.min.js"></script>
#     <![endif]-->
# <script type="text/javascript">
#      window.cookieconsent_options = {"message":"Diese Webseite verwendet Cookies, um Ihnen eine bestm&ouml;gliche Nutzung zu erm&ouml;glichen.","dismiss":"OK","learnMore":"Mehr Informationen","link":"https://www.free-your-stuff.com/de/datenschutz","theme":false};
#     </script>
# </meta>
# </meta>
# </head>
# <body>
# <header class="main">
# <div class="container">
# <div class="row">
# <div class="col-md-3 col-sm-3 hidden-xs logo">
# <a href="https://www.free-your-stuff.com/de">
# <img alt="Free Your Stuff" class="img-responsive" src="/images/logo.png"/>
# </a>
# </div>
# <div class="col-md-6 col-sm-6 paddingless-xs">
# <div class="navbar-header navbar-default">
# <button class="navbar-toggle pull-right" data-target="#navbar-collapse-01" data-toggle="collapse" type="button">
# <span class="sr-only">
#          Toggle navigation
#         </span>
# <span class="fa fa-chevron-down">
# </span>
# </button>
# <a class="navbar-brand hidden-sm hidden-md hidden-lg" href="https://www.free-your-stuff.com/de">
# <img alt="Free Your Stuff" height="30" src="/images/logo.png" width="127"/>
# </a>
# </div>
# <div class="collapse navbar-collapse" id="navbar-collapse-01">
# <ul class="nav navbar-nav">
# <li class="visible-xs">
# <a href="https://www.free-your-stuff.com/de/register" title="Registrieren">
#           Registrieren
#          </a>
# </li>
# <li class="visible-xs">
# <a href="https://www.free-your-stuff.com/de/login" title="Anmelden">
#           Anmelden
#          </a>
# </li>
# <li>
# <a href="https://www.free-your-stuff.com/de/was-ist-free-your-stuff">
#           Was ist Free Your Stuff?
#          </a>
# </li>
# <li>
# <a href="https://www.free-your-stuff.com/de/hilfe">
#           Hilfe
#          </a>
# </li>
# <li>
# <a href="https://www.free-your-stuff.com/de/kontakt">
#           Kontakt
#          </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-md-3 col-sm-3 hidden-xs">
# <div class="media fys-blue-bg userbox">
# <div class="media-body media-register media-body-md media-padding hidden-sm">
# <div class="col-md-12">
# <p>
#           Registriere dich jetzt und mach mit bei
#           <strong>
#            Free Your Stuff!
#           </strong>
# </p>
# </div>
# <div class="col-md-12">
# <a class="pull-left text-nowrap" href="https://www.free-your-stuff.com/de/register" title="Registrieren">
# <span class="fa fa-pencil-square-o">
# </span>
#           Registrieren
#          </a>
# <a class="pull-right" href="https://www.free-your-stuff.com/de/login" title="Anmelden">
# <span class="fa fa-sign-in">
# </span>
#           Anmelden
#          </a>
# </div>
# </div>
# <div class="media-log visible-sm">
# <div class="row">
# <div class="col-sm-12 text-center">
# <a href="https://www.free-your-stuff.com/de/register" title="Registrieren">
# <span class="fa fa-pencil-square-o">
# </span>
#            Registrieren
#           </a>
# </div>
# <div class="col-sm-12 text-center">
# <a href="https://www.free-your-stuff.com/de/login" title="Anmelden">
# <span class="fa fa-sign-in">
# </span>
#            Anmelden
#           </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="container">
# <div class="row call-header">
# <div class="col-md-6">
# <div class="fys-green-bg header-left">
# <div class="row top-line">
# <div class="col-xxs-9 col-xs-9 col-sm-10">
# <h1>
# <span class="header-prepend">
#           Free Your Stuff
#          </span>
#          Berlin
#         </h1>
# </div>
# <div class="col-xxs-3 col-xs-3 col-sm-2">
# <div class="weather-widget">
# <span class="degrees">
#           4 °C
#          </span>
# <span class="weather-icon">
# <i data-icon="I">
# </i>
# </span>
# </div>
# </div>
# </div>
# <div class="row hidden-xxs">
# <div class="col-md-12">
# <small>
#          Weitere Gebiete in der Umgebung:
#         </small>
# <div class="zip-links">
# <a href="https://www.free-your-stuff.com/de/berlin/10115">
#           10115
#          </a>
# <a href="https://www.free-your-stuff.com/de/berlin/10117">
#           10117
#          </a>
# <a href="https://www.free-your-stuff.com/de/berlin/10119">
#           10119
#          </a>
# <a href="https://www.free-your-stuff.com/de/berlin/10178">
#           10178
#          </a>
# <a href="https://www.free-your-stuff.com/de/berlin/10179">
#           10179
#          </a>
# <a href="https://www.free-your-stuff.com/de/berlin/10243">
#           10243
#          </a>
# <a href="https://www.free-your-stuff.com/de/berlin/10245">
#           10245
#          </a>
# <a href="https://www.free-your-stuff.com/de/berlin/10247">
#           10247
#          </a>
# <a href="https://www.free-your-stuff.com/de/berlin/10249">
#           10249
#          </a>
# <a href="https://www.free-your-stuff.com/de/berlin/10315">
#           10315
#          </a>
# <a href="https://www.free-your-stuff.com/de/berlin/10317">
#           10317
#          </a>
# <a href="https://www.free-your-stuff.com/de/berlin/10318">
#           10318
#          </a>
# <a href="https://www.free-your-stuff.com/de/berlin/10319">
#           10319
#          </a>
# <a href="https://www.free-your-stuff.com/de/berlin/10365">
#           10365
#          </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-3 big-btn hidden-xs">
# <a class="btn-give" href="https://www.free-your-stuff.com/de/me/gives/add">
# <strong>
#        GIVE
#       </strong>
#       erstellen
#      </a>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-3 big-btn hidden-xs">
# <a class="btn-need" href="https://www.free-your-stuff.com/de/me/needs/add">
# <strong>
#        NEED
#       </strong>
#       erstellen
#      </a>
# </div>
# <div class="col-xxs-6 col-xs-6 big-btn visible-xs text-center">
# <a class="btn bold btn-block btn-show-give" href="https://www.free-your-stuff.com/de/me/gives/add">
# <i class="fa fa-plus">
# </i>
# <strong>
#        GIVE
#       </strong>
#       erstellen
#      </a>
# </div>
# <div class="col-xxs-6 col-xs-6 big-btn visible-xs text-center">
# <a class="btn bold btn-block btn-show-need" href="https://www.free-your-stuff.com/de/me/needs/add">
# <i class="fa fa-plus">
# </i>
# <strong>
#        NEED
#       </strong>
#       erstellen
#      </a>
# </div>
# </div>
# </div>
# <div class="container main-container">
# <div class="row search-bar">
# <div class="col-xxs-12 col-xs-6 col-md-3">
# <div class="form-group">
# <div class="input-group greenmile">
# <input class="form-control" name="q" placeholder="Suchbegriff eingeben..." type="text" value=""/>
# <span class="input-group-addon">
# <button id="search-submit" type="submit">
# <i class="fa fa-search">
# </i>
# </button>
# </span>
# </div>
# </div>
# </div>
# <div class="col-xxs-12 col-xs-6 col-md-3">
# <div class="form-group">
# <div class="input-group blueocean">
# <input autocomplete="off" class="form-control" data-selected="berlin" id="zip-autocomplete" name="zip" placeholder="Postleitzahl / Ort..." type="text" value="Berlin"/>
# <span class="input-group-addon">
# <button type="submit">
# <i class="fa fa-map-marker">
# </i>
# </button>
# </span>
# </div>
# <div class="suggestions-wrapper">
# </div>
# <span class="show-zip-needed" data-tipso="Ort oder Postleitzahl eigeben um nach Entfernung zu sortieren.">
# </span>
# </div>
# </div>
# <div class="col-xxs-12 col-xs-6 col-md-3">
# <div class="form-group">
# <select class="form-control custom-select" data-class="pinkfruit" data-icon="fa fa-archive" id="category-select" name="category">
# <option value="">
#         Alle Kategorien
#        </option>
# <option value="wohnen-garten">
#         Wohnen &amp; Garten
#        </option>
# <option value="moebel-lampen">
#         Möbel &amp; Lampen
#        </option>
# <option value="elektronik-technik">
#         Elektronik &amp; Technik
#        </option>
# <option value="buecher-filme-musik">
#         Bücher, Filme &amp; Musik
#        </option>
# <option value="mode-fashion">
#         Mode &amp; Fashion
#        </option>
# <option value="kind-baby">
#         Kind &amp; Baby
#        </option>
# <option value="freizeit-sport">
#         Freizeit &amp; Sport
#        </option>
# <option value="auto-motor">
#         Auto &amp; Motor
#        </option>
# <option value="gutscheine-tickets">
#         Gutscheine &amp; Tickets
#        </option>
# <option value="lebensmittel">
#         Lebensmittel
#        </option>
# <option value="haustiere-zubehoer">
#         Haustiere &amp; Zubehör
#        </option>
# <option value="sonstiges">
#         Sonstiges
#        </option>
# </select>
# </div>
# </div>
# <div class="col-xxs-12 col-xs-6 col-md-3">
# <div class="row">
# <div class="col-md-12">
# <div class="form-group">
# <select class="form-control custom-select" data-class="silverstar" data-icon="fa fa-tasks" id="order-select" name="order">
# <option value="distance">
#           nach Entfernug
#          </option>
# <option selected="selected" value="new">
#           neuste zuerst
#          </option>
# <option value="popular">
#           nach Beliebtheit
#          </option>
# </select>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row bread-crumb visible-xxs visible-xs">
# <div class="col-xxs-12">
# <ol class="breadcrumb breadcrumb-border-top breadcrumb-none">
# <li class="breadcrumb-element">
# <a href="https://www.free-your-stuff.com/de">
#         Deutschland
#        </a>
# </li>
# <li class="breadcrumb-element">
# <a href="https://www.free-your-stuff.com/de/berlin">
#         Berlin
#        </a>
# </li>
# </ol>
# </div>
# </div>
# <div class="row bread-crumb">
# <div class="col-md-12">
# <ol class="breadcrumb breadcrumb-border-top breadcrumb-none">
# <li class="product-type product-type-none">
#        1640 Ergebnisse
#       </li>
# <li class="breadcrumb-element hidden-xxs hidden-xs">
# <a href="https://www.free-your-stuff.com/de">
#         Deutschland
#        </a>
# </li>
# <li class="breadcrumb-element hidden-xxs hidden-xs">
# <a href="https://www.free-your-stuff.com/de/berlin">
#         Berlin
#        </a>
# </li>
# <li class="hidden" data-filter-type-give="false" data-filter-type-need="false">
# </li>
# <li class="pull-right">
# <a class="product-type product-type-need" href="#" id="type-picked-need">
#         NEEDS
#        </a>
# </li>
# <li class="pull-right">
# <a class="product-type product-type-give" href="#" id="type-picked-give">
#         GIVES
#        </a>
# </li>
# </ol>
# </div>
# </div>
# <div class="row">
# <div class="col-xs-12 col-sm-12 col-md-6 product-entry">
# <article class="search-result">
# <div class="row">
# <div class="col-xxs-12 col-xs-6 img-holder">
# <div class="img-container">
# <div class="product-type product-type-give">
#           GIVE
#          </div>
# <div class="product-type-feedback">
# <div class="row">
# <div class="col-xs-12 text-right">
# <div class="pins">
# <i class="fa fa-heart">
# </i>
#              0
#             </div>
# </div>
# </div>
# </div>
# <a class="loading-img-give" href="https://www.free-your-stuff.com/de/gives/berlin/10999/moebel-lampen/twin-meridian-rollo-von-jab-D1GEkB.html">
# <img alt="Twin meridian Rollo von JAB" class="img-responsive product-main-image b-lazy" data-src="https://www.free-your-stuff.com/img/cache/preview/ff7d21af6d6f4e02c55d089166657dde8b07ca5d.jpg" data-src-small="https://www.free-your-stuff.com/img/cache/large/ff7d21af6d6f4e02c55d089166657dde8b07ca5d.jpg" src="..."/>
# </a>
# </div>
# </div>
# <div class="col-xxs-12 col-xs-6 paddingless-md padding-lg-left-none">
# <div class="timer">
# <i class="fa fa-clock-o">
# </i>
#          vor 1 Tag
#         </div>
# <div class="title">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/10999/moebel-lampen/twin-meridian-rollo-von-jab-D1GEkB.html">
# <h4>
#            Twin meridian Rollo von...
#           </h4>
# </a>
# </div>
# <div class="description">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/10999/moebel-lampen/twin-meridian-rollo-von-jab-D1GEkB.html">
# <p>
#            Twin meridian Rollo von JAB. Halb-Transparent. Perfekter Zustand.
#
# Breite: 235cm Höhe: 170cm
#
# Farbe: PG 3...
#           </p>
# </a>
# </div>
# <div class="location">
# <a href="https://www.free-your-stuff.com/de/berlin">
# <i class="fa fa-map-marker">
# </i>
#           10999 Berlin
#          </a>
# </div>
# <div class="call-to-action no-gutter">
# <div class="col-xs-6">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/10999/moebel-lampen/twin-meridian-rollo-von-jab-D1GEkB.html">
# <span class="btn bold btn-show-give">
# <span class="visible-xxs-inline hidden-xs hidden-md">
# <i class="fa fa-check">
# </i>
# </span>
#             Weitere Details
#            </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </article>
# </div>
# <div class="col-xs-12 col-sm-12 col-md-6 product-entry">
# <article class="search-result">
# <div class="row">
# <div class="col-xxs-12 col-xs-6 img-holder">
# <div class="img-container">
# <div class="product-type product-type-give">
#           GIVE
#          </div>
# <div class="product-type-feedback">
# <div class="row">
# <div class="col-xs-12 text-right">
# <div class="pins">
# <i class="fa fa-heart">
# </i>
#              0
#             </div>
# </div>
# </div>
# </div>
# <a class="loading-img-give" href="https://www.free-your-stuff.com/de/gives/berlin/10119/moebel-lampen/ecksofa-grau-gebraucht-aber-in-gutem-zustand-qzl64Q.html">
# <img alt="Ecksofa grau gebraucht aber in gutem Zustand" class="img-responsive product-main-image b-lazy" data-src="https://www.free-your-stuff.com/img/cache/preview/91ebc039b24a333890f94e1cf712806448a584fe.jpg" data-src-small="https://www.free-your-stuff.com/img/cache/large/91ebc039b24a333890f94e1cf712806448a584fe.jpg" src="..."/>
# </a>
# </div>
# </div>
# <div class="col-xxs-12 col-xs-6 paddingless-md padding-lg-left-none">
# <div class="timer">
# <i class="fa fa-clock-o">
# </i>
#          vor 5 Tagen
#         </div>
# <div class="title">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/10119/moebel-lampen/ecksofa-grau-gebraucht-aber-in-gutem-zustand-qzl64Q.html">
# <h4>
#            Ecksofa grau gebraucht a...
#           </h4>
# </a>
# </div>
# <div class="description">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/10119/moebel-lampen/ecksofa-grau-gebraucht-aber-in-gutem-zustand-qzl64Q.html">
# <p>
#            Ich verschenke dieses bequeme Ecksofa. Das Sofa ist gebraucht und weist einige
# Gebrauchsspuren auf - die Text...
#           </p>
# </a>
# </div>
# <div class="location">
# <a href="https://www.free-your-stuff.com/de/berlin">
# <i class="fa fa-map-marker">
# </i>
#           10119 Berlin
#          </a>
# </div>
# <div class="call-to-action no-gutter">
# <div class="col-xs-6">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/10119/moebel-lampen/ecksofa-grau-gebraucht-aber-in-gutem-zustand-qzl64Q.html">
# <span class="btn bold btn-show-give">
# <span class="visible-xxs-inline hidden-xs hidden-md">
# <i class="fa fa-check">
# </i>
# </span>
#             Weitere Details
#            </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </article>
# </div>
# <div class="col-xs-12 col-sm-12 col-md-6 product-entry">
# <article class="search-result">
# <div class="row">
# <div class="col-xxs-12 col-xs-6 img-holder">
# <div class="img-container">
# <div class="product-type product-type-give">
#           GIVE
#          </div>
# <div class="product-type-feedback">
# <div class="row">
# <div class="col-xs-12 text-right">
# <div class="pins">
# <i class="fa fa-heart">
# </i>
#              2
#             </div>
# </div>
# </div>
# </div>
# <a class="loading-img-give" href="https://www.free-your-stuff.com/de/gives/berlin/12047/moebel-lampen/bettsofa-zu-verschenken-QPayED.html">
# <img alt="Bettsofa zu verschenken " class="img-responsive product-main-image b-lazy" data-src="https://www.free-your-stuff.com/img/cache/preview/93e4da2b1b3373111017711e7bdda70b5ec41d3b.jpg" data-src-small="https://www.free-your-stuff.com/img/cache/large/93e4da2b1b3373111017711e7bdda70b5ec41d3b.jpg" src="..."/>
# </a>
# </div>
# </div>
# <div class="col-xxs-12 col-xs-6 paddingless-md padding-lg-left-none">
# <div class="timer">
# <i class="fa fa-clock-o">
# </i>
#          vor 2 Wochen
#         </div>
# <div class="title">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/12047/moebel-lampen/bettsofa-zu-verschenken-QPayED.html">
# <h4>
#            Bettsofa zu verschenken
#           </h4>
# </a>
# </div>
# <div class="description">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/12047/moebel-lampen/bettsofa-zu-verschenken-QPayED.html">
# <p>
#            Ein gut erhaltenes Sofa kann abgeholt werden. Maße:  ca. 150(B) X 90(T) X 89(H Rückenlehne); 64 (H Armlehnen);...
#           </p>
# </a>
# </div>
# <div class="location">
# <a href="https://www.free-your-stuff.com/de/berlin">
# <i class="fa fa-map-marker">
# </i>
#           12047 Berlin
#          </a>
# </div>
# <div class="call-to-action no-gutter">
# <div class="col-xs-6">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/12047/moebel-lampen/bettsofa-zu-verschenken-QPayED.html">
# <span class="btn bold btn-show-give">
# <span class="visible-xxs-inline hidden-xs hidden-md">
# <i class="fa fa-check">
# </i>
# </span>
#             Weitere Details
#            </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </article>
# </div>
# <div class="col-xs-12 col-sm-12 col-md-6 product-entry">
# <article class="search-result">
# <div class="row">
# <div class="col-xxs-12 col-xs-6 img-holder">
# <div class="img-container">
# <div class="product-type product-type-give">
#           GIVE
#          </div>
# <div class="product-type-feedback">
# <div class="row">
# <div class="col-xs-12 text-right">
# <div class="pins">
# <i class="fa fa-heart">
# </i>
#              0
#             </div>
# </div>
# </div>
# </div>
# <a class="loading-img-give" href="https://www.free-your-stuff.com/de/gives/berlin/12159/wohnen-garten/retro-ofen-einbauherd-privileg-classic-4400n-D1GZzB.html">
# <img alt="Retro Ofen Einbauherd Privileg Classic 4400N" class="img-responsive product-main-image b-lazy" data-src="https://www.free-your-stuff.com/img/cache/preview/00d177183841a7ce76ba976f929685d0dfbff3b0.jpg" data-src-small="https://www.free-your-stuff.com/img/cache/large/00d177183841a7ce76ba976f929685d0dfbff3b0.jpg" src="..."/>
# </a>
# </div>
# </div>
# <div class="col-xxs-12 col-xs-6 paddingless-md padding-lg-left-none">
# <div class="timer">
# <i class="fa fa-clock-o">
# </i>
#          vor 2 Wochen
#         </div>
# <div class="title">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/12159/wohnen-garten/retro-ofen-einbauherd-privileg-classic-4400n-D1GZzB.html">
# <h4>
#            Retro Ofen Einbauherd Pr...
#           </h4>
# </a>
# </div>
# <div class="description">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/12159/wohnen-garten/retro-ofen-einbauherd-privileg-classic-4400n-D1GZzB.html">
# <p>
#            Ich habe es für zusätzliche Kapazität verwendet. Ich brauche es jetzt nicht mehr. Funktioniert gut.
#           </p>
# </a>
# </div>
# <div class="location">
# <a href="https://www.free-your-stuff.com/de/berlin">
# <i class="fa fa-map-marker">
# </i>
#           12159 Berlin
#          </a>
# </div>
# <div class="call-to-action no-gutter">
# <div class="col-xs-6">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/12159/wohnen-garten/retro-ofen-einbauherd-privileg-classic-4400n-D1GZzB.html">
# <span class="btn bold btn-show-give">
# <span class="visible-xxs-inline hidden-xs hidden-md">
# <i class="fa fa-check">
# </i>
# </span>
#             Weitere Details
#            </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </article>
# </div>
# <div class="col-xs-12 col-sm-12 col-md-6 product-entry">
# <article class="search-result">
# <div class="row">
# <div class="col-xxs-12 col-xs-6 img-holder">
# <div class="img-container">
# <div class="product-type product-type-give">
#           GIVE
#          </div>
# <div class="product-type-feedback">
# <div class="row">
# <div class="col-xs-12 text-right">
# <div class="pins">
# <i class="fa fa-heart">
# </i>
#              2
#             </div>
# </div>
# </div>
# </div>
# <a class="loading-img-give" href="https://www.free-your-stuff.com/de/gives/berlin/10247/moebel-lampen/bed-mattress-everything-in-the-photos-q6GMYB.html">
# <img alt="Bed + Mattress + Everything in the photos" class="img-responsive product-main-image b-lazy" data-src="https://www.free-your-stuff.com/img/cache/preview/cae682c594919df35e4c8517146f8a80fcb3099c.jpg" data-src-small="https://www.free-your-stuff.com/img/cache/large/cae682c594919df35e4c8517146f8a80fcb3099c.jpg" src="..."/>
# </a>
# </div>
# </div>
# <div class="col-xxs-12 col-xs-6 paddingless-md padding-lg-left-none">
# <div class="timer">
# <i class="fa fa-clock-o">
# </i>
#          vor 2 Wochen
#         </div>
# <div class="title">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/10247/moebel-lampen/bed-mattress-everything-in-the-photos-q6GMYB.html">
# <h4>
#            Bed + Mattress + Everyth...
#           </h4>
# </a>
# </div>
# <div class="description">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/10247/moebel-lampen/bed-mattress-everything-in-the-photos-q6GMYB.html">
# <p>
#            Bed + Mattress : 140 x 200 (IKEA, used only for 4 months)
# You take the bed and the mattress and you receive e...
#           </p>
# </a>
# </div>
# <div class="location">
# <a href="https://www.free-your-stuff.com/de/berlin">
# <i class="fa fa-map-marker">
# </i>
#           10247 Berlin
#          </a>
# </div>
# <div class="call-to-action no-gutter">
# <div class="col-xs-6">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/10247/moebel-lampen/bed-mattress-everything-in-the-photos-q6GMYB.html">
# <span class="btn bold btn-show-give">
# <span class="visible-xxs-inline hidden-xs hidden-md">
# <i class="fa fa-check">
# </i>
# </span>
#             Weitere Details
#            </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </article>
# </div>
# <div class="col-xs-12 col-sm-12 col-md-6 product-entry">
# <article class="search-result">
# <div class="row">
# <div class="col-xxs-12 col-xs-6 img-holder">
# <div class="img-container">
# <div class="product-type product-type-need">
#           NEED
#          </div>
# <div class="product-type-feedback">
# <div class="row">
# <div class="col-xs-12 text-right">
# <div class="pins">
# <i class="fa fa-reply">
# </i>
#              0
#             </div>
# </div>
# </div>
# </div>
# <a class="loading-img-need" href="https://www.free-your-stuff.com/de/needs/berlin/12489/moebel-lampen/need-a-matratze-mattress-Bgv3wq.html">
# <img alt="Need a  Matratze (Mattress)" class="img-responsive product-main-image b-lazy" data-src="https://www.free-your-stuff.com/images/no-product_318.png" data-src-small="https://www.free-your-stuff.com/images/no-product_318.png" src="..."/>
# </a>
# </div>
# </div>
# <div class="col-xxs-12 col-xs-6 paddingless-md padding-lg-left-none">
# <div class="timer">
# <i class="fa fa-clock-o">
# </i>
#          vor 2 Wochen
#         </div>
# <div class="title">
# <a href="https://www.free-your-stuff.com/de/needs/berlin/12489/moebel-lampen/need-a-matratze-mattress-Bgv3wq.html">
# <h4>
#            Need a  Matratze (Mattre...
#           </h4>
# </a>
# </div>
# <div class="description">
# <a href="https://www.free-your-stuff.com/de/needs/berlin/12489/moebel-lampen/need-a-matratze-mattress-Bgv3wq.html">
# <p>
#            I need a single bed Mattress.
#           </p>
# </a>
# </div>
# <div class="location">
# <a href="https://www.free-your-stuff.com/de/berlin">
# <i class="fa fa-map-marker">
# </i>
#           12489 Berlin
#          </a>
# </div>
# <div class="call-to-action no-gutter">
# <div class="col-xs-6">
# <a href="https://www.free-your-stuff.com/de/needs/berlin/12489/moebel-lampen/need-a-matratze-mattress-Bgv3wq.html">
# <span class="btn bold btn-show-need">
# <span class="visible-xxs-inline hidden-xs hidden-md">
# <i class="fa fa-check">
# </i>
# </span>
#             Weitere Details
#            </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </article>
# </div>
# <div class="col-xs-12 col-sm-12 col-md-6 product-entry">
# <article class="search-result">
# <div class="row">
# <div class="col-xxs-12 col-xs-6 img-holder">
# <div class="img-container">
# <div class="product-type product-type-give">
#           GIVE
#          </div>
# <div class="product-type-feedback">
# <div class="row">
# <div class="col-xs-12 text-right">
# <div class="pins">
# <i class="fa fa-heart">
# </i>
#              0
#             </div>
# </div>
# </div>
# </div>
# <a class="loading-img-give" href="https://www.free-your-stuff.com/de/gives/berlin/10247/moebel-lampen/sofa-qzlkRQ.html">
# <img alt="Sofa" class="img-responsive product-main-image b-lazy" data-src="https://www.free-your-stuff.com/img/cache/preview/6830c784c7dd21b7dbf0223518d896f5293340ec.jpg" data-src-small="https://www.free-your-stuff.com/img/cache/large/6830c784c7dd21b7dbf0223518d896f5293340ec.jpg" src="..."/>
# </a>
# </div>
# </div>
# <div class="col-xxs-12 col-xs-6 paddingless-md padding-lg-left-none">
# <div class="timer">
# <i class="fa fa-clock-o">
# </i>
#          vor 3 Wochen
#         </div>
# <div class="title">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/10247/moebel-lampen/sofa-qzlkRQ.html">
# <h4>
#            Sofa
#           </h4>
# </a>
# </div>
# <div class="description">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/10247/moebel-lampen/sofa-qzlkRQ.html">
# <p>
#            7 year sofa the material is starting to go away but the sofa and bed is still comfortable. With the cover or t...
#           </p>
# </a>
# </div>
# <div class="location">
# <a href="https://www.free-your-stuff.com/de/berlin">
# <i class="fa fa-map-marker">
# </i>
#           10247 Berlin
#          </a>
# </div>
# <div class="call-to-action no-gutter">
# <div class="col-xs-6">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/10247/moebel-lampen/sofa-qzlkRQ.html">
# <span class="btn bold btn-show-give">
# <span class="visible-xxs-inline hidden-xs hidden-md">
# <i class="fa fa-check">
# </i>
# </span>
#             Weitere Details
#            </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </article>
# </div>
# <div class="col-xs-12 col-sm-12 col-md-6 product-entry">
# <article class="search-result">
# <div class="row">
# <div class="col-xxs-12 col-xs-6 img-holder">
# <div class="img-container">
# <div class="product-type product-type-need">
#           NEED
#          </div>
# <div class="product-type-feedback">
# <div class="row">
# <div class="col-xs-12 text-right">
# <div class="pins">
# <i class="fa fa-reply">
# </i>
#              0
#             </div>
# </div>
# </div>
# </div>
# <a class="loading-img-need" href="https://www.free-your-stuff.com/de/needs/berlin/10829/sonstiges/koffer-BXrlpD.html">
# <img alt="Koffer" class="img-responsive product-main-image b-lazy" data-src="https://www.free-your-stuff.com/images/no-product_308.png" data-src-small="https://www.free-your-stuff.com/images/no-product_308.png" src="..."/>
# </a>
# </div>
# </div>
# <div class="col-xxs-12 col-xs-6 paddingless-md padding-lg-left-none">
# <div class="timer">
# <i class="fa fa-clock-o">
# </i>
#          vor 3 Wochen
#         </div>
# <div class="title">
# <a href="https://www.free-your-stuff.com/de/needs/berlin/10829/sonstiges/koffer-BXrlpD.html">
# <h4>
#            Koffer
#           </h4>
# </a>
# </div>
# <div class="description">
# <a href="https://www.free-your-stuff.com/de/needs/berlin/10829/sonstiges/koffer-BXrlpD.html">
# <p>
#            Suche ein großes Kostenloses Koffer. Danke.
#           </p>
# </a>
# </div>
# <div class="location">
# <a href="https://www.free-your-stuff.com/de/berlin">
# <i class="fa fa-map-marker">
# </i>
#           10829 Berlin
#          </a>
# </div>
# <div class="call-to-action no-gutter">
# <div class="col-xs-6">
# <a href="https://www.free-your-stuff.com/de/needs/berlin/10829/sonstiges/koffer-BXrlpD.html">
# <span class="btn bold btn-show-need">
# <span class="visible-xxs-inline hidden-xs hidden-md">
# <i class="fa fa-check">
# </i>
# </span>
#             Weitere Details
#            </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </article>
# </div>
# <div class="col-xs-12 col-sm-12 col-md-6 product-entry">
# <article class="search-result">
# <div class="row">
# <div class="col-xxs-12 col-xs-6 img-holder">
# <div class="img-container">
# <div class="product-type product-type-give">
#           GIVE
#          </div>
# <div class="product-type-feedback">
# <div class="row">
# <div class="col-xs-12 text-right">
# <div class="pins">
# <i class="fa fa-heart">
# </i>
#              0
#             </div>
# </div>
# </div>
# </div>
# <a class="loading-img-give" href="https://www.free-your-stuff.com/de/gives/berlin/10437/elektronik-technik/kleine-waschmaschine-qpVN1Q.html">
# <img alt="Kleine Waschmaschine " class="img-responsive product-main-image b-lazy" data-src="https://www.free-your-stuff.com/images/no-product_317.png" data-src-small="https://www.free-your-stuff.com/images/no-product_317.png" src="..."/>
# </a>
# </div>
# </div>
# <div class="col-xxs-12 col-xs-6 paddingless-md padding-lg-left-none">
# <div class="timer">
# <i class="fa fa-clock-o">
# </i>
#          vor 4 Wochen
#         </div>
# <div class="title">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/10437/elektronik-technik/kleine-waschmaschine-qpVN1Q.html">
# <h4>
#            Kleine Waschmaschine
#           </h4>
# </a>
# </div>
# <div class="description">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/10437/elektronik-technik/kleine-waschmaschine-qpVN1Q.html">
# <p>
#            Sie funktioniert nicht mehr ganz.
# Bereit zum abholen!
#           </p>
# </a>
# </div>
# <div class="location">
# <a href="https://www.free-your-stuff.com/de/berlin">
# <i class="fa fa-map-marker">
# </i>
#           10437 Berlin
#          </a>
# </div>
# <div class="call-to-action no-gutter">
# <div class="col-xs-6">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/10437/elektronik-technik/kleine-waschmaschine-qpVN1Q.html">
# <span class="btn bold btn-show-give">
# <span class="visible-xxs-inline hidden-xs hidden-md">
# <i class="fa fa-check">
# </i>
# </span>
#             Weitere Details
#            </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </article>
# </div>
# <div class="col-xs-12 col-sm-12 col-md-6 product-entry">
# <article class="search-result">
# <div class="row">
# <div class="col-xxs-12 col-xs-6 img-holder">
# <div class="img-container">
# <div class="product-type product-type-give">
#           GIVE
#          </div>
# <div class="product-type-feedback">
# <div class="row">
# <div class="col-xs-12 text-right">
# <div class="pins">
# <i class="fa fa-heart">
# </i>
#              2
#             </div>
# </div>
# </div>
# </div>
# <a class="loading-img-give" href="https://www.free-your-stuff.com/de/gives/berlin/10555/wohnen-garten/kleiderschrank-200-x-60-x-180-l-b-h-QEXPPB.html">
# <img alt="Kleiderschrank 200 x 60 x 180 (L, B, H)" class="img-responsive product-main-image b-lazy" data-src="https://www.free-your-stuff.com/img/cache/preview/1aeeae29be367688d4d6f91c163443f624539b95.jpg" data-src-small="https://www.free-your-stuff.com/img/cache/large/1aeeae29be367688d4d6f91c163443f624539b95.jpg" src="..."/>
# </a>
# </div>
# </div>
# <div class="col-xxs-12 col-xs-6 paddingless-md padding-lg-left-none">
# <div class="timer">
# <i class="fa fa-clock-o">
# </i>
#          vor 4 Wochen
#         </div>
# <div class="title">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/10555/wohnen-garten/kleiderschrank-200-x-60-x-180-l-b-h-QEXPPB.html">
# <h4>
#            Kleiderschrank 200 x 60...
#           </h4>
# </a>
# </div>
# <div class="description">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/10555/wohnen-garten/kleiderschrank-200-x-60-x-180-l-b-h-QEXPPB.html">
# <p>
#            Geräumiger Kleiderschrank mit Gebrauchspuren kostenlos abzugeben - Selbstabholer - Der Schrank ist abgebaut, a...
#           </p>
# </a>
# </div>
# <div class="location">
# <a href="https://www.free-your-stuff.com/de/berlin">
# <i class="fa fa-map-marker">
# </i>
#           10555 Berlin
#          </a>
# </div>
# <div class="call-to-action no-gutter">
# <div class="col-xs-6">
# <a href="https://www.free-your-stuff.com/de/gives/berlin/10555/wohnen-garten/kleiderschrank-200-x-60-x-180-l-b-h-QEXPPB.html">
# <span class="btn bold btn-show-give">
# <span class="visible-xxs-inline hidden-xs hidden-md">
# <i class="fa fa-check">
# </i>
# </span>
#             Weitere Details
#            </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </article>
# </div>
# </div>
# <div class="row text-center">
# <ul class="pagination">
# <li class="active">
# <a href="https://www.free-your-stuff.com/de/berlin?page=1">
#        1
#       </a>
# </li>
# <li class="">
# <a href="https://www.free-your-stuff.com/de/berlin?page=2">
#        2
#       </a>
# </li>
# <li class="">
# <a href="https://www.free-your-stuff.com/de/berlin?page=3">
#        3
#       </a>
# </li>
# <li class="">
# <a href="https://www.free-your-stuff.com/de/berlin?page=4">
#        4
#       </a>
# </li>
# <li class="">
# <a href="https://www.free-your-stuff.com/de/berlin?page=5">
#        5
#       </a>
# </li>
# <li class="">
# <a href="https://www.free-your-stuff.com/de/berlin?page=6">
#        6
#       </a>
# </li>
# <li class="">
# <a href="https://www.free-your-stuff.com/de/berlin?page=7">
#        7
#       </a>
# </li>
# <li class="">
# <a href="https://www.free-your-stuff.com/de/berlin?page=8">
#        8
#       </a>
# </li>
# <li>
# <span>
#        ...
#       </span>
# </li>
# <li class="">
# <a href="https://www.free-your-stuff.com/de/berlin?page=164">
#        164
#       </a>
# </li>
# </ul>
# </div>
# </div>
# <!-- /.container -->
# <footer>
# <div class="container">
# <div class="row">
# <div class="col-sm-7 clearfix">
# <h3 class="footer-title">
#        Was ist Free-Your-Stuff.com?
#       </h3>
# <p>
#        Free-Your-Stuff.com ist ein kostenloser online Marktplatz für alle die etwas zu verschenken haben und
#                     geschenkt bekommen möchten. Ob Accessoires für das Wohnzimmer, Taschen, Babyausstattung, Handys oder vielleicht sogar ein Haus. Ganz egal!
#                     Es gibt immer etwas zu verschenken, das andere noch gebrauchen können.
#       </p>
# </div>
# <div class="col-sm-5 footer-right-col">
# <div class="footer-banner">
# <h3 class="footer-title">
#         Newsletter
#        </h3>
# <p>
#         Sign up to our newsletter to know when it is available in your country!
#        </p>
# <form action="https://free-your-stuff.us8.list-manage.com/subscribe/post?u=322d249a09902c9db855f6410&amp;id=a7747848f2" method="post">
# <div class="input-group">
# <input autocomplete="off" class="form-control" name="EMAIL" placeholder="E-Mail eingeben" required="" type="email"/>
# <input name="b_322d249a09902c9db855f6410_a7747848f2" type="hidden" value=""/>
# <span class="input-group-btn">
# <button class="btn btn-dark btn-flat" type="submit">
# <i class="fa fa-envelope">
# </i>
# </button>
# </span>
# </div>
# </form>
# <div class="footer-links text-right">
# <a href="https://www.free-your-stuff.com/de/datenschutz" title="Datenschutz">
#          Datenschutz
#         </a>
#         |
#         <a href="https://www.free-your-stuff.com/de/impressum" title="Impressum">
#          Impressum
#         </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <!-- Load JS here for greater good =============================-->
# <script src="https://www.free-your-stuff.com/js/cookie.min.js?v=1455576242">
# </script>
# <script src="https://www.free-your-stuff.com/js/jquery-1.11.3.min.js?v=1449530151">
# </script>
# <script src="https://www.free-your-stuff.com/js/jquery-ias.min.js?v=1449530156">
# </script>
# <script src="https://www.free-your-stuff.com/js/sidebar.js?v=1449530142">
# </script>
# <script src="https://www.free-your-stuff.com/js/jquery-ui-1.10.3.custom.min.js?v=1449530148">
# </script>
# <script src="https://www.free-your-stuff.com/js/jquery.ui.touch-punch.min.js?v=1449530144">
# </script>
# <script src="https://www.free-your-stuff.com/bootstrap/js/bootstrap.min.js?v=1449530174">
# </script>
# <script src="https://www.free-your-stuff.com/js/jquery.sumoselect.js?v=1449530165">
# </script>
# <script src="https://www.free-your-stuff.com/js/jquery.autocomplete.js?v=1449530140">
# </script>
# <script src="https://www.free-your-stuff.com/js/flatui-checkbox.js?v=1449530145">
# </script>
# <script src="https://www.free-your-stuff.com/js/flatui-radio.js?v=1449530159">
# </script>
# <script src="https://www.free-your-stuff.com/js/jquery.tagsinput.js?v=1449530162">
# </script>
# <script src="https://www.free-your-stuff.com/js/jquery.placeholder.js?v=1449530147">
# </script>
# <script src="https://www.free-your-stuff.com/js/lightbox.js?v=1449530160">
# </script>
# <script src="https://www.free-your-stuff.com/js/blazy.min.js?v=1449530164">
# </script>
# <script src="https://www.free-your-stuff.com/js/scripts.js?v=1513201922">
# </script>
# <script src="https://www.free-your-stuff.com/js/socket.io.js?v=1452556801">
# </script>
# <script src="https://www.free-your-stuff.com/js/search.js?v=1465203393">
# </script>
# <script src="https://www.free-your-stuff.com/js/numbermodal.js?v=1476738640">
# </script>
# <script src="https://www.free-your-stuff.com/js/notifications.js?v=1465157126">
# </script>
# <script src="https://www.free-your-stuff.com/js/application.js?v=1513201924">
# </script>
# <script type="text/javascript">
#    var gaProperty = 'UA-49609396-1';
#             var disableStr = 'ga-disable-' + gaProperty;
#             if (document.cookie.indexOf(disableStr + '=true') > -1) {
#                 window[disableStr] = true;
#             }
#             function gaOptout() {
#                 document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
#                 window[disableStr] = true;
#                 alert('Das Tracking durch Google Analytics wurde in Ihrem Browser für diese Website deaktiviert.');
#             }
#   </script>
# <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#             (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#             m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#             })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#             ga('create', 'UA-49609396-1', 'free-your-stuff.com');
#             ga('set', 'anonymizeIp', true);
#             ga('send', 'pageview');
#   </script>
# </body>
# </html>

# %%
# Clean up the data a little bit

price = price.strip()[1:]
title = title.strip()

print(title)
print(price)

# %%
# Create a Timestamp for your output to track when data was collected

import datetime

today = datetime.date.today()

print(today)

# %%
# Create CSV and write headers and data into the file

import csv 

header = ['Title', 'Price', 'Date']
data = [title, price, today]


with open('AmazonWebScraperDataset.csv', 'w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\alexf\AmazonWebScraperDataset.csv')

print(df)

# %%
#Now we are appending data to the csv

with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
#Combine all of the above code into one function


def check_price():
    URL = 'https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data%2Banalyst%2Btshirt&qid=1626655184&sr=8-3&customId=B0752XJYNL&th=1'

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page = requests.get(URL, headers=headers)

    soup1 = BeautifulSoup(page.content, "html.parser")

    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

    title = soup2.find(id='productTitle').get_text()

    price = soup2.find(id='priceblock_ourprice').get_text()

    price = price.strip()[1:]
    title = title.strip()

    import datetime

    today = datetime.date.today()
    
    import csv 

    header = ['Title', 'Price', 'Date']
    data = [title, price, today]

    with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
# Runs check_price after a set time and inputs data into your CSV

while(True):
    check_price()
    time.sleep(86400)

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\alexf\AmazonWebScraperDataset.csv')

print(df)

# %%
# If uou want to try sending yourself an email (just for fun) when a price hits below a certain level you can try it
# out with this script

def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('AlexTheAnalyst95@gmail.com','xxxxxxxxxxxxxx')
    
    subject = "The Shirt you want is below $15! Now is your chance to buy!"
    body = "Alex, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here: https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data+analyst+tshirt&qid=1626655184&sr=8-3"
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'AlexTheAnalyst95@gmail.com',
        msg
     
    )
